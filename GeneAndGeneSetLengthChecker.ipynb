# %%
#Checks number of genesets
import pandas as pd
import csv
import os

# %%
library = pd.read_csv('PredictionTSVs/GeneRIFPredictions/Enrichr_GO_Molecular_Function_2018_Predictions_GeneRIF_Cooccurrence.tsv', sep = '\t', index_col = 0, header = None)

# %%
#library.drop(1, axis = 1, inplace = True)
library.head()
print(len(library.index))
library.head()
# Out:
# 1151
#                                                     1       2       3    \
# 0
# semaphorin receptor activity (GO:0017154)           NaN  PLXNA1  PLXNA2
# 7SK snRNA binding (GO:0097322)                      NaN  HEXIM2   CCNT2
# androgen receptor binding (GO:0050681)              NaN      AR    ESR1
# transcription regulatory region DNA binding (GO...  NaN   EP300     MYC
# protein phosphatase inhibitor activity (GO:0004...  NaN  PPP1CA  PPP1CC
#
#                                                         4       5       6    \
# 0
# semaphorin receptor activity (GO:0017154)            SEMA3A  PLXNA3  SEMA4D
# 7SK snRNA binding (GO:0097322)                        CCNT1  HEXIM1    CDK9
# androgen receptor binding (GO:0050681)                SUMO1   NCOA1   CCND1
# transcription regulatory region DNA binding (GO...      SP1   HDAC1  CTNNB1
# protein phosphatase inhibitor activity (GO:0004...  PPP2R2B    PTPA  PPP2CA
#
# ...

# %% [markdown]
# print(library.index)
